# %%
"""数据集中存在中括号，代表这里的词有多种分法，这里就出问题了"""

# %%
from itertools import chain
import json

# %%
def PIES(word):
    l = len(word)
    if l==1:
        return["S"]
    else:
        return ["B"]+["I"]*(l-2)+["E"]

# %%
def preprocessing(sent):
    # 得到词
    sents = sent.strip("\n").split("\t")
    words =[i.split("/")[0] for i in sents]
    # 得到label
    label_pre = [i.split("/")[1] for i in sents]
    label = [[j]*len(i) for i,j in zip(words,label_pre)]
    ## 分词记录
    pos = [PIES(i) for i in words]
    # 转成一维
    words = "".join(words)
    label = list(chain.from_iterable(label))
    pos = list(chain.from_iterable(pos))
    return [words, pos,label]

# %%
data =[]
with open("./People's_Daily/clean_199801.txt",encoding="utf-8") as f:
    for l in f:
        data.append(preprocessing(l))

# %%
with open("./People's_Daily//wdata.json","w") as f:
    json.dump(data,f)

# %%
words = [i[0] for i in data]

# %%
labels = [i[2] for i in data]

# %%
len(labels)
# Out:
# 19484

# %%
len(list(chain.from_iterable(words)))
# Out:
# 1850895

# %%
len(set(chain.from_iterable(words)))
# Out:
# 4688

# %%
vocab = set(chain.from_iterable(words))
print(vocab)
# Out:
# {'揽', '轿', '场', '还', '亡', '瀚', '蛤', '棋', '殃', '乡', '懊', '采', '广', '零', '踩', '能', '亵', '扫', '酗', '榻', '腰', '酒', '吊', '闯', '郑', '秸', '疑', '垠', '整', '姗', '翅', '麓', '腥', '蘑', '遐', '镶', '淘', '萄', '诀', '晋', '找', '巅', '＋', '簇', '契', '玛', '囊', '祜', '炙', '惶', '录', '晤', '识', '濑', '④', '洲', '甸', '钠', '潘', '萍', '媲', '阅', '梢', '杆', '眺', '篱', '厕', '稽', '银', '射', '挎', 'ｇ', '邈', '峻', '艾', '障', '洇', '[', '虹', '余', '蛛', '题', '嬉', '彼', '刑', '创', '裟', '匐', '凤', '夙', '暾', '隆', '百', '’', '牌', '衍', '厝', '镝', '蹿', '决', '叱', '％', '卖', '鸡', '川', '幸', '迅', '绚', '拙', '逆', '卸', '走', '登', '雾', '鳇', '错', '革', '卿', '叙', '婢', '放', '宏', '何', '妆', '鲟', '夹', '料', '颗', '翎', '瞬', '贲', '跨', '塞', '雕', '鸯', '汨', '；', '匹', '港', '苞', '族', '侍', '逐', '慧', '霉', '粥', '籽', '隘', '二', '滞', '矫', '筑', '巾', '肋', '侣', '盾', '菱', '婴', '癸', '状', '款', '龋', '尖', '菇', '枉', '肪', '靓', '馆', '挣', '阀', '苜', '掣', '掳', '唐', '试', '猿', '湘', '槌', '杀', '厉', '锄', '谚', '印', '晨', '洒', '除', '助', '虽', '嫁', '砰', '闫', '檀', '疤', '据', '择', '豆', '嗣', '瘾', '特', '陨', '怖', '闭', '囿', '坊', '滁', '舫', '徊', '臭', '噶', '坚', '斧', '赝', '话', '珮', '衰', '宽', '炭', '狰', '驷', '埃', '帽', '诗', '预', '懿', '鹬', '伴', '缜', '贤', '呆', '鹈', '上', '斐', '刁', '剁', '仁', '俏', '肖', '捷', '斤', '宙', '窕', '牧', '石', 'Ｔ', '忒', '驿', '均', '集', '膛', '羊', '牵', '利', '腾', '咽', '俞', '侠', '醚', '邦', '止', '畜', '棚', '炽', '尼', '禹', '嫖', '锣', '伙', '务', '俊', '佑', '蛙', '埤', '锌', '莹', '屿', '饿', '鸠', '茏', '壁', '丙', '重', '退', '冲', '拎', '甥', '梵', '铲', '吻', '鎏', '太', '驻', '锁', '芯', '作', '铅', '宰', '锹', '＞', '炜', '磨', '弧', '厩', '叔', '苔', '灸', '绯', '嫌', '示', '摘', '国', '筱', '煦', '香', '抵', '碧', '珙', '胚', '兢', '账', '衮', '奕', '派', '咄', '治', '晏', '麦', '攀', '逮', '补', '澳', '屹', '解', '吴', '弊', '坦', '炎', '之', '产', '戛', '玉', '挝', '延', '龄', '奎', '蓟', '涸', '眯', '滂', '瓤', '３', '战', '芝', '喻', '肽', '７', '长', '交', '阁', '呸', '源', '给', '缆', '漉', '破', '撞', '分', '肴', '暇', '柔', '投', '诘', '通', '澎', '漏', '兰', '钩', '稔', '羔', '轧', '吓', '郡', 'Ｗ', '娅', '针', '唇', '冯', '翊', '钜', '岱', '庸', '瞎', '邢', '久', '烤', '纫', '倾', '乒', '絮', '邮', '衩', '括', '玄', '谣', '罹', '沌', '凰', '喟', '酹', '醒', '叮', '阙', '桓', '法', '扭', '接', '篇', '锤', '写', '鞋', '进', '衽', '敏', '践', '嵌', '貂', '其', '愣', '坑', '咒', '褪', '收', '峨', 'Ａ', '葺', '袁', '铭', '桕', '往', '眶', '俾', '远', '休', '邛', '傈', '措', '珩', '痔', '烙', '职', '涨', '槐', '码', '垦', '辨', '妒', '价', '跪', '闺', '酱', '擒', '狄', '谦', '泽', '涧', '鹑', '砺', '幡', '璈', '背', '苛', '及', '覆', '髻', '牛', '痍', '鸭', '适', '亲', '胜', '慈', '泳', '牟', '锃', '碱', '了', '粕', '洼', '赚', '咸', '娱', '恨', '窥', '队', '改', '贯', '祸', '禁', '脚', '渊', '宜', '遇', '顷', '汰', '昔', '褂', '刈', '髌', '歼', '逊', '将', '鸵', '诵', 'Ｈ', '莺', '谐', '猛', '匝', '晓', '谷', '豫', '汕', '履', '雁', '邳', '饪', '馥', '匡', '铄', '拗', '苋', '喧', '吩', '笨', '幽', '仨', '擦', '役', '屎', '圩', '间', '扬', '横', '亦', '旦', '轴', '浓', '希', '尾', 'ｓ', '嗲', '插', '稳', '昙', '拨', '磕', '惫', '塬', '绸', '侦', '殇', '划', '凑', '偃', '恒', '诫', '崂', '润', '咧', '伸', '跳', '敛', '无', '匕', '伎', '互', '涉', '世', '搭', '窜', '皱', '祺', '板', '徐', '灵', '孢', '十', '支', '叨', '堇', '峒', '弘', '问', '胀', 'ｄ', '咝', '村', '栖', '匠', '恶', '伍', '撇', '寻', '杯', '辈', '父', '骤', '篪', '旨', '省', '嗖', '蜡', '骼', '付', '谤', '载', '紫', '五', '屏', '穹', '搓', '血', '斟', '驾', '塔', '跆', '立', '饱', '求', '觉', '滥', '害', '羡', '崩', '真', '暖', '蛐', '糊', '悼', '次', '黔', '荩', '猩', '蜓', '岩', '渐', '矍', '姨', '佳', '回', '擘', '飨', '悠', '演', '棠', '戌', '廷', '锴', '荧', '哼', '酮', '碍', '聊', '挠', '萸', '抗', '略', '袈', '地', '蔬', '缘', '蔓', '帙', '荡', '岳', '氦', '航', '送', '魅', '鸪', '庇', '肆', '爪', '喷', '扑', '矶', '屠', '误', '熙', '梨', '轲', '膏', '稞', '随', '毋', '撒', '赔', '裤', '央', '翘', '瘟', '缮', '憧', '督', '磊', '桅', '边', '没', '浮', '钥', '线', '苏', '拾', '奉', '需', '奸', '淫', '铆', '垂', '妪', '葫', '漱', '骁', '罐', '婷', '芳', '抿', 'Ｃ', '鉴', '辊', '莘', '璃', '拦', '祁', '衣', '鸣', '用', '式', '菲', '砻', '污', '薪', '媾', '龇', '钧', '穗', '见', '租', '淡', '鹅', '诃', '行', '韫', '缝', '疚', '宇', '栋', '沓', '非', '桂', '溢', '炕', '鲜', '搜', '虾', '吆', '短', '灰', '享', '址', '框', '茗', '况', '亭', '蕻', '规', '筛', '蚀', '生', '具', '徇', '服', '撑', '赐', '项', '轰', '颐', '陌', '者', '盆', '怎', '恺', '卧', '潜', '瓷', '蛀', '沧', '爷', '虫', '迢', '傲', ...

# %%
set(chain.from_iterable(labels))
# Out:
# {'Ag',
#  'Bg',
#  'Dg',
#  'Mg',
#  'Ng',
#  'Ng]',
#  'Rg',
#  'Tg',
#  'Vg',
#  'Yg',
#  'a',
#  'ad',
#  'an',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'h',
#  'i',
#  'i]',
#  'j',
#  'j]',
#  'k',
#  'l',
#  'l]',
#  'm',
#  'n',
#  'n]',
#  'na',
#  'nr',
#  'nr]',
#  'ns',
#  'ns]',
#  'nt',
#  'nt]',
#  'nx',
#  'nx]',
#  'nz',
#  'nz]',
#  'o',
#  'p',
#  'q',
#  'q]',
#  'r',
#  's',
#  's]',
#  't',
#  'u',
#  'v',
#  'v]',
#  'vd',
#  'vn',
#  'vn]',
#  'vvn',
#  'w',
#  'y',
#  'z'}

# %%
word2id = {}
id2word = {}
for i,word in enumerate(vocab):
    word2id[word] = i
    id2word[i] = word

# %%
PIES("中")
# Out:
# ['S']

# %%
preprocessing(sent)
# Out:
# (['中', '共', '中', '央', '总', '书', '记', '、', '国', '家', '主', '席', '江', '泽', '民'],
#  ['B', 'I', 'I', 'E', 'B', 'I', 'E', 'S', 'B', 'E', 'B', 'E', 'B', 'I', 'E'],
#  ['nt',
#   'nt',
#   'nt',
#   'nt',
#   'n',
#   'n',
#   'n',
#   'w',
#   'n',
#   'n',
#   'n',
#   'n',
#   'nr',
#   'nr',
#   'nr'])

# %%
sent = "中共中央/nt	总书记/n	、/w	国家/n	主席/n	江泽民/nr"
words =[i.split("/")[0] for i in sent.split("\t")] 
print(words)
labels = [i.split("/")[1] for i in sent.split("\t")]
print(labels)
pos = [PIES(i) for i in words]
print(pos)
# Out:
# ['中共中央', '总书记', '、', '国家', '主席', '江泽民']
# ['nt', 'n', 'w', 'n', 'n', 'nr']
# [['B', 'I', 'I', 'E'], ['B', 'I', 'E'], ['S'], ['B', 'E'], ['B', 'E'], ['B', 'I', 'E']]

# %%
label2 = [[j]*len(i) for i,j in zip(words,labels)]
print(label2)
# Out:
# [['nt', 'nt', 'nt', 'nt'], ['n', 'n', 'n'], ['w'], ['n', 'n'], ['n', 'n'], ['nr', 'nr', 'nr']]

# %%
import re

# %%
ss = ["中共中央/nt	总书记/n	、/w	国家/n	主席/n	江泽民/nr","中共中央/nt	[总书记/n	、/w	国家/n	主席/n]/ns	江泽民/nr"]

# %%
if re.match(".*\[.*\].*",ss[1]):
    print(re.match(".*\[.*\].*",ss[1]))
# Out:
# <re.Match object; span=(0, 39), match='中共中央/nt\t[总书记/n\t、/w\t国家/n\t主席/n]/ns\t江泽民/nr'>

# %%
if re.match(".*\[.*\].*",ss[0]):
    print(re.match(".*\[.*\].*",ss[0]))
